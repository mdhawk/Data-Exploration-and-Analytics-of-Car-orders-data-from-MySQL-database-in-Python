# %% [markdown]
# # 1 Pre-Processing

# %%
# Load Python libraries
import pandas as pd
import sqlalchemy
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Connect to Database to access the Cars data table
engine = sqlalchemy.create_engine('mysql+pymysql://root@localhost:3306/final')

# %%
#Load the cars database table into a Pandas dataframe named cars
cars = pd.read_sql_table("temp",engine)

# %%
#Convert OrderDate and ShipDate dataframe column into Datetime, since the OrderDate and ShipDate column are of type String inside the database's cars table 
cars['OrderDate']= pd.to_datetime(cars['OrderDate']) 
cars['ShipDate']= pd.to_datetime(cars['ShipDate'])

# %%
#Check the data types of each column of the cars dataframe to see if all columns are in correct and expected format
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 33 columns):
# SupplierID                1000 non-null int64
# SupplierAddress           1000 non-null object
# SupplierName              1000 non-null object
# SupplierContactDetails    1000 non-null object
# ProductID                 1000 non-null int64
# CarMaker                  1000 non-null object
# CarModel                  1000 non-null object
# CarColor                  1000 non-null object
# CarModelYear              1000 non-null int64
# CarPrice                  1000 non-null float64
# CustomerID                1000 non-null object
# CustomerName              1000 non-null object
# Gender                    1000 non-null object
# JobTitle                  1000 non-null object
# PhoneNumber               1000 non-null object
# EmailAddress              1000 non-null object
# City                      1000 non-null object
# Country                   1000 non-null object
# CountryCode               1000 non-null object
# State                     1000 non-null object
# CustomerAddress           1000 non-null object
# OrderDate                 1000 non-null datetime64[ns]
# OrderID                   1000 non-null object
# ShipDate                  1000 non-null datetime64[ns]
# ShipMode                  1000 non-null object
# Shipping                  1000 non-null object
# PostalCode                1000 non-null int64
# Sales                     1000 non-null float64
# Quantity                  1000 non-null int64
# Discount                  1000 non-null float64
# CreditCardType            1000 non-null object
# CreditCard                1000 non-null int64
# CustomerFeedback          1000 non-null object
# dtypes: datetime64[ns](2), float64(3), int64(6), object(22)
# memory usage: 257.9+ KB

# %% [markdown]
# # 2 Data Exploration

# %% [markdown]
# ## 2.1 Customer Feedback

# %%
#Executing SQL queries using Python to pull the Customer Feedback related data from the database. 
query = '''select CustomerFeedback,count(*) as Count from temp group by CustomerFeedback;'''
df = pd.read_sql_query(query,engine)
#Bar plot of Number of Orders per Customer Feedback categories
ax=df.set_index('CustomerFeedback').Count.plot(kind='bar',figsize=(7,7),fontsize=12,color=['orangered', 'yellowgreen','orange','red','g'],rot=0)
ax.set_xlabel("Customer Feedback",fontsize=20)
ax.set_ylabel("Number of Orders",fontsize=20)
# Add this loop to add the annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(
        '{:}'.format(height), 
        (p.get_x()+.5*width, p.get_y() + height + 2), 
        ha='center',
        fontsize=12
    );

# %%
#Executing SQL queries using Python to pull the Shipping related data from the database. 
query = '''select Shipping,count(*) as Count from temp group by Shipping;'''
df = pd.read_sql_query(query,engine)
#Bar plot of Number of Orders per Shipping categories
ax=df.set_index('Shipping').Count.plot(kind='bar',figsize=(7,7),fontsize=12,color=['b', 'g'],rot=0)
ax.set_xlabel("Shipping",fontsize=20)
ax.set_ylabel("Number of Orders",fontsize=20)
# Add this loop to add the annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(
        '{:}'.format(height), 
        (p.get_x()+.5*width, p.get_y() + height + 5), 
        ha='center',
        fontsize=12
    );

# %% [markdown]
# ## 2.2 Gender

# %%
#Executing SQL queries using Python to pull the Gender related data from the database. 
query = '''select Gender,count(*) as number_of_orders, ROUND(sum(Sales)/1000000, 2) as Total_sales_in_Millions,ROUND((sum(Sales)/count(*))/1000000 , 2)  as Average_saleprice_per_order_in_Millions from temp group by Gender;'''
df = pd.read_sql_query(query,engine)

# %%
#Bar plot of Number of Orders per Gender categories
ax=df.set_index('Gender').number_of_orders.plot(kind='bar',figsize=(4,7),fontsize=12,color=['b', 'g'],rot=0)
ax.set_xlabel("Gender",fontsize=20)
ax.set_ylabel("Number of Orders",fontsize=20)
# Add this loop to add the annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(
        '{:}'.format(height), 
        (p.get_x()+.5*width, p.get_y() + height + 5), 
        ha='center',
        fontsize=12
    );

# %%
#Bar plot of Number of Orders per Gender categories
ax=df.set_index('Gender').Total_sales_in_Millions.plot(kind='bar',figsize=(4,7),fontsize=12,color=['b', 'g'],rot=0)
ax.set_xlabel("Gender",fontsize=20)
ax.set_ylabel("Total Sales(in Millions)",fontsize=20)
# Add this loop to add the annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(
        '{:}'.format(height), 
        (p.get_x()+.5*width, p.get_y() + height + 5), 
        ha='center',
        fontsize=12
    );

# %%
#Pie plot of % of Number of Orders per Gender categories
ax=df.set_index('Gender')['number_of_orders'].plot.pie(subplots=False, figsize=(7,7), textprops={'fontsize': 15}, autopct='%1.1f%%',
        startangle=90)
ax.set_xlabel('Gender wise % of Number of Orders',fontsize=20)
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
#Pie plot of % of Total Sales per Gender categories
ax=df.set_index('Gender')['Total_sales_in_Millions'].plot.pie(subplots=False, figsize=(7,7), textprops={'fontsize': 15}, autopct='%1.1f%%',
        startangle=90)
ax.set_xlabel('Gender wise % of Total Sales',fontsize=20)
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## 2.3 Car Brand:

# %% [markdown]
# ### 2.3.1 Car brand wise Number of Orders

# %%
#Executing SQL queries using Python to pull the Car brand related data from the database. 
query = '''select CarMaker,count(*) as number_of_orders, ROUND(sum(Sales)/1000000, 2) as Total_sales_in_Millions,ROUND((sum(Sales)/count(*))/1000000 , 2)  as Average_saleprice_per_order_in_Millions from temp group by CarMaker;'''
df = pd.read_sql_query(query,engine)

# %%
#Bar plot of Number of Orders for each Car brands
ax=df.set_index('CarMaker').number_of_orders.plot(kind='bar',figsize=(20,10),rot=90,fontsize=17)
ax.set_xlabel("Car Brand",fontsize=30)
ax.set_ylabel("Number of Orders",fontsize=30)
# Add this loop to add the annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(
        '{:}'.format(height), 
        (p.get_x()+.5*width, p.get_y() + height + 1), 
        ha='center',
        fontsize=12
    );

# %% [markdown]
# ### 2.3.2 Car brand wise Total Sales of cars(in Millions)

# %%
#Bar plot of Total Sales(in Millions) for each Car brands
ax=df.set_index('CarMaker').Total_sales_in_Millions.plot(kind='bar',figsize=(20,10),rot=90,fontsize=17)
ax.set_xlabel("Car Brand",fontsize=30)
ax.set_ylabel("Total Sales(in Millions)",fontsize=30)
# Add this loop to add the annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(
        '{:.1f}'.format(height), 
        (p.get_x()+.5*width, p.get_y() + height + 1), 
        ha='center',
        fontsize=12
    );

# %% [markdown]
# ### 2.3.3 Car brand wise  Average Selling Price per Order(in Millions)

# %%
#Bar plot of Average Selling Price per Order(in Millions) for each Car brands
ax=df.set_index('CarMaker').Average_saleprice_per_order_in_Millions.plot(kind='bar',figsize=(20,10),rot=90,fontsize=17)
ax.set_xlabel("Car Brand",fontsize=30)
ax.set_ylabel("Avg Selling Price per order(in Millions)",fontsize=30)
# Add this loop to add the annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(
        '{:.2f}'.format(height), 
        (p.get_x()+.5*width, p.get_y() + height + 0.01), 
        ha='center',
        fontsize=9
    );

# %% [markdown]
# ### 2.3.4 Car brand wise Sales Market share

# %%
#Pie chart of Market share by Sales for each Car brand
ax=df.set_index('CarMaker')['Total_sales_in_Millions'].plot.pie(subplots=False, figsize=(20,20), textprops={'fontsize': 12}, autopct='%1.1f%%',
        startangle=65)
ax.set_xlabel('Car brand wise Sales Market share',fontsize=30)
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## 2.4 State:

# %% [markdown]
# ### 2.4.1 State wise Number of Orders

# %%
#Executing SQL queries using Python to pull the State related data from the database. 
query = '''select State,count(*) as number_of_orders, ROUND(sum(Sales)/1000000, 2) as Total_sales_in_Millions,ROUND((sum(Sales)/count(*))/1000000 , 2)  as Average_saleprice_per_order_in_Millions from temp group by State;'''
df = pd.read_sql_query(query,engine)

# %%
#Bar plot of Number of Orders for each State
ax=df.set_index('State').number_of_orders.plot(kind='bar',figsize=(20,10),rot=90,fontsize=17)
ax.set_xlabel("State",fontsize=30)
ax.set_ylabel("Number of Orders",fontsize=30)
# Add this loop to add the annotations
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(
        '{:}'.format(height), 
        (p.get_x()+.5*width, p.get_y() + height + 1), 
        ha='center',
        fontsize=12
    );

# %% [markdown]
# ### 2.4.2 State wise Total sales of cars(in Millions)

# %%
#Bar plot of Total Sales(in Millions) for each State
ax=df.set_index('State').Total_sales_in_Millions.plot(kind='bar',figsize=(20,10),rot=90,fontsize=17)
ax.set_xlabel("State",fontsize=30)
ax.set_ylabel("Total Sales(in Millions)",fontsize=30)
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(
        '{:.1f}'.format(height), 
        (p.get_x()+.5*width, p.get_y() + height + 1), 
        ha='center',
        fontsize=11
    );

# %% [markdown]
# ### 2.4.3 Car brand wise Average Selling Price per Order(in Millions)

# %%
#Bar plot of Average Selling Price per Order(in Millions) for each State
ax=df.set_index('State').Average_saleprice_per_order_in_Millions.plot(kind='bar',figsize=(20,10),rot=90,fontsize=17)
ax.set_xlabel("State",fontsize=30)
ax.set_ylabel("Avg Selling Price per order(in Millions)",fontsize=30)
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(
        '{:.2f}'.format(height), 
        (p.get_x()+.5*width, p.get_y() + height + 0.01), 
        ha='center',
        fontsize=9
    );

# %% [markdown]
# ### 2.4.4 State wise Sales Market share

# %%
#Pie chart of Market share by Sales for each State
ax=df.set_index('State')['Total_sales_in_Millions'].plot.pie(subplots=False, figsize=(20,20), textprops={'fontsize': 12}, autopct='%1.1f%%',
        startangle=0)
ax.set_xlabel('State wise Sales Market share',fontsize=30)
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# # 3 Data Analytics

# %% [markdown]
# ## 3.1 Clustering/segmentation of Car Brands using KMeans algo into HIGH EARNER, MEDIUM EARNER and LOW EARNER

# %%
#Executing SQL queries using Python to pull the Car brand related data from the database.
query = '''select CarMaker,count(*) as number_of_orders, ROUND(sum(Sales)/1000000, 2) as Total_sales_in_Millions,ROUND((sum(Sales)/count(*))/1000000 , 2)  as Average_saleprice_per_order_in_Millions from temp group by CarMaker;'''
df = pd.read_sql_query(query,engine)

# %%
#Importing KMeans Clustering algorithm from Sklearn Python library
#Create 3 Clusters using KMeans algo based on the columns number_of_orders & Average_saleprice_per_order_in_Millions from the dataframe named df
from sklearn.cluster import KMeans
import numpy as np
kmeans = KMeans(n_clusters=3, random_state=0).fit(df[['Average_saleprice_per_order_in_Millions','number_of_orders']])
kmeans.labels_
# Out:
# array([0, 0, 2, 0, 0, 2, 1, 2, 1, 2, 0, 0, 1, 0, 0, 1, 0, 1, 2, 2, 2, 2,
#        2, 0, 2, 0, 0, 2, 2, 0, 0, 0, 1, 1, 2, 0, 0, 1, 0, 2, 0, 0, 1, 0,
#        0, 0, 0, 0, 0, 2, 2, 1, 1, 2])

# %%
#Creating a temporary dataframe to store the Cluster values created using KMeans algorithm
temp=pd.DataFrame(kmeans.labels_)
temp.columns = ['Cluster']

# %%
#Concatenating the original dataframe along with a new column which contains the Clustering values returned by the KMeans algorithm
temp = pd.concat([df, temp], axis=1, join_axes=[df.index])
# Out:
# C:\Users\mdami\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.

# %%
#Creating a new column named Demand_Cluster based on the Clustering values returned by KMeans algo
#if KMeans value =1 then HIGH EARNER
#if KMeans value =2 then MEDIUM EARNER
#if KMeans value =0 then LOW EARNER
temp.loc[temp.Cluster ==2, 'Demand_Cluster'] = 'MEDIUM EARNER' 
temp.loc[temp.Cluster ==1, 'Demand_Cluster'] = 'HIGH EARNER' 
temp.loc[temp.Cluster ==0, 'Demand_Cluster'] = 'LOW EARNER'

# %%
#Original View based on the Number of Orders and Average Selling Price per Order (in Million $), points are colored by Car Brands
#sns.set(font_scale=0.9)
g=sns.lmplot( x='Average_saleprice_per_order_in_Millions', y='number_of_orders', data=df, fit_reg=False, hue='CarMaker', legend=True,height=8)
g.set_axis_labels("Average Selling Price per Order (in Million $)",
 "Number of Orders")

# %%
#Clustered View based on Number of Orders and Average Selling Price per Order (in Million $), points are colored by Clustering values
g=sns.lmplot( y='number_of_orders',x='Average_saleprice_per_order_in_Millions', data=temp, fit_reg=False, hue='Demand_Cluster', legend=True,height=8)
g.set_axis_labels("Average Selling Price per Order (in Million $)", "Number of Orders")
plt.show(g)

# %%
#A view of the final data frame consisting of the Car Brand data and Cluster column(gives values that was generated using KMeans algo)
#and Demand_Cluster column(gives values as HIGH EARNER, MEDIUM EARNER AND LOW EARNER based on Clustering values)
temp
# Out:
#          CarMaker  number_of_orders  Total_sales_in_Millions  \
# 0           Acura                11                     9.69
# 1    Aston Martin                 2                     1.79
# 2            Audi                25                    21.50
# 3          Austin                 1                     0.78
# 4         Bentley                 6                     5.23
# 5             BMW                28                    23.74
# 6           Buick                40                    34.88
# 7        Cadillac                18                    15.28
# 8       Chevrolet                83                    70.99
# 9        Chrysler                14                    11.92
# 10        Citroën                 1                     0.85
# 11         Daewoo                 1                     0.82
# 12          Dodge                50                    42.18
# 13          Eagle                 4                     3.38
# 14        Ferrari                 6                     4.86
# 15           Ford                63                    54.01
# 16            Geo                 4                     3.54
# 17            GMC                37                    31.42
# 18          Honda                19                    16.09
# 19        Hyundai                14                    12.32
# 20       Infiniti                16                    13.88
# 21          Isuzu                18                    15.46
# 22         Jaguar                13                    11.65
# 23           Jeep                11                     9.95
# 24            Kia                16                    13.36
# 25    Lamborghini                 8                     7.03
# 26     Land Rover                10                     8.73
# 27          Lexus                18                    15.52
# 28        Lincoln                16                    13.89
# 29          Lotus                 4                     3.58
# 30       Maserati                 6                     5.17
# 31        Maybach                 3                     2.67
# 32          Mazda                43                    36.81
# 33  Mercedes-Benz                45                    38.33
# 34        Mercury                15                    12.62
# 35             MG                 1                     0.83
# 36           MINI                 2                     1.67
# 37     Mitsubishi                41                    34.50
# 38         Morgan                 3                     2.34
# 39         Nissan                31                    25.63
# 40     Oldsmobile                12                    10.35
# 41       Plymouth                 8                     7.17
# 42        Pontiac                50                    41.30
# 43        Porsche                 7                     6.18
# 44            Ram                 1                     0.76
# 45    Rolls-Royce                 2                     1.89
# 46           Saab                11                     9.28
# 47         Saturn                 2                     1.78
# 48          Scion                 3                     2.41
# 49         Subaru                22                    18.31
# 50         Suzuki                22                    18.77
# 51         Toyota                52                    43.74
# 52     Volkswagen                35                    29.94
# 53          Volvo                26                    22.34
#
#     Average_saleprice_per_order_in_Millions  Cluster Demand_Cluster
# 0                                      0.88        0     LOW EARNER
# 1                                      0.89        0     LOW EARNER
# 2                                      0.86        2  MEDIUM EARNER
# 3                                      0.78        0     LOW EARNER
# 4                                      0.87        0     LOW EARNER
# 5                                      0.85        2  MEDIUM EARNER
# 6                                      0.87        1    HIGH EARNER
# 7                                      0.85        2  MEDIUM EARNER
# 8                                      0.86        1    HIGH EARNER
# 9                                      0.85        2  MEDIUM EARNER
# 10                                     0.85        0     LOW EARNER
# 11                                     0.82        0     LOW EARNER
# 12                                     0.84        1    HIGH EARNER
# 13                                     0.85        0     LOW EARNER
# 14                                     0.81        0     LOW EARNER
# 15                                     0.86        1    HIGH EARNER
# 16                                     0.88        0     LOW EARNER
# 17                                     0.85        1    HIGH EARNER
# 18                                     0.85        2  MEDIUM EARNER
# 19                                     0.88        2  MEDIUM EARNER
# 20                                     0.87        2  MEDIUM EARNER
# 21                                     0.86        2  MEDIUM EARNER
# 22                                     0.90        2  MEDIUM EARNER
# 23                                     0.90        0     LOW EARNER
# 24                                     0.83        2  MEDIUM EARNER
# 25                                     0.88        0     LOW EARNER
# 26                                     0.87        0     LOW EARNER
# 27                                     0.86        2  MEDIUM EARNER
# 28                                     0.87        2  MEDIUM EARNER
# 29                                     0.90        0     LOW EARNER
# 30                                     0.86        0     LOW EARNER
# 31                                     0.89        0     LOW EARNER
# 32                                     0.86        1    HIGH EARNER
# 33                                     0.85        1    HIGH EARNER
# 34                                     0.84        2  MEDIUM EARNER
# 35                                     0.83        0     LOW EARNER
# 36                                     0.84        0     LOW EARNER
# 37                                     0.84        1    HIGH EARNER
# 38                                     0.78        0     LOW EARNER
# 39                                     0.83        2  MEDIUM EARNER
# 40                                     0.86        0     LOW EARNER
# 41                                     0.90        0     LOW EARNER
# 42                                     0.83        1    HIGH EARNER
# 43                                     0.88        0     LOW EARNER
# 44                                     0.76        0     LOW EARNER
# 45                                     0.95        0     LOW EARNER
# 46                                     0.84        0     LOW EARNER
# 47                                     0.89        0     LOW EARNER
# 48                                     0.80        0     LOW EARNER
# 49                                     0.83        2  MEDIUM EARNER
# 50                                     0.85        2  MEDIUM EARNER
# 51                                     0.84        1    HIGH EARNER
# 52                                     0.86        1    HIGH EARNER
# 53                                     0.86        2  MEDIUM EARNER

# %%
#Lets check the Car Brands from the HIGH EARNER cluster
temp[temp['Cluster']==1]
# Out:
#          CarMaker  number_of_orders  Total_sales_in_Millions  \
# 6           Buick                40                    34.88
# 8       Chevrolet                83                    70.99
# 12          Dodge                50                    42.18
# 15           Ford                63                    54.01
# 17            GMC                37                    31.42
# 32          Mazda                43                    36.81
# 33  Mercedes-Benz                45                    38.33
# 37     Mitsubishi                41                    34.50
# 42        Pontiac                50                    41.30
# 51         Toyota                52                    43.74
# 52     Volkswagen                35                    29.94
#
#     Average_saleprice_per_order_in_Millions  Cluster Demand_Cluster
# 6                                      0.87        1    HIGH EARNER
# 8                                      0.86        1    HIGH EARNER
# 12                                     0.84        1    HIGH EARNER
# 15                                     0.86        1    HIGH EARNER
# 17                                     0.85        1    HIGH EARNER
# 32                                     0.86        1    HIGH EARNER
# 33                                     0.85        1    HIGH EARNER
# 37                                     0.84        1    HIGH EARNER
# 42                                     0.83        1    HIGH EARNER
# 51                                     0.84        1    HIGH EARNER
# 52                                     0.86        1    HIGH EARNER

# %%
#Lets check the Car Brands from the MEDIUM EARNER cluster
temp[temp['Cluster']==2]
# Out:
#     CarMaker  number_of_orders  Total_sales_in_Millions  \
# 2       Audi                25                    21.50
# 5        BMW                28                    23.74
# 7   Cadillac                18                    15.28
# 9   Chrysler                14                    11.92
# 18     Honda                19                    16.09
# 19   Hyundai                14                    12.32
# 20  Infiniti                16                    13.88
# 21     Isuzu                18                    15.46
# 22    Jaguar                13                    11.65
# 24       Kia                16                    13.36
# 27     Lexus                18                    15.52
# 28   Lincoln                16                    13.89
# 34   Mercury                15                    12.62
# 39    Nissan                31                    25.63
# 49    Subaru                22                    18.31
# 50    Suzuki                22                    18.77
# 53     Volvo                26                    22.34
#
#     Average_saleprice_per_order_in_Millions  Cluster Demand_Cluster
# 2                                      0.86        2  MEDIUM EARNER
# 5                                      0.85        2  MEDIUM EARNER
# 7                                      0.85        2  MEDIUM EARNER
# 9                                      0.85        2  MEDIUM EARNER
# 18                                     0.85        2  MEDIUM EARNER
# 19                                     0.88        2  MEDIUM EARNER
# 20                                     0.87        2  MEDIUM EARNER
# 21                                     0.86        2  MEDIUM EARNER
# 22                                     0.90        2  MEDIUM EARNER
# 24                                     0.83        2  MEDIUM EARNER
# 27                                     0.86        2  MEDIUM EARNER
# 28                                     0.87        2  MEDIUM EARNER
# 34                                     0.84        2  MEDIUM EARNER
# 39                                     0.83        2  MEDIUM EARNER
# 49                                     0.83        2  MEDIUM EARNER
# 50                                     0.85        2  MEDIUM EARNER
# 53                                     0.86        2  MEDIUM EARNER

# %%
#Lets check the Car Brands from the LOW EARNER cluster
temp[temp['Cluster']==0]
# Out:
#         CarMaker  number_of_orders  Total_sales_in_Millions  \
# 0          Acura                11                     9.69
# 1   Aston Martin                 2                     1.79
# 3         Austin                 1                     0.78
# 4        Bentley                 6                     5.23
# 10       Citroën                 1                     0.85
# 11        Daewoo                 1                     0.82
# 13         Eagle                 4                     3.38
# 14       Ferrari                 6                     4.86
# 16           Geo                 4                     3.54
# 23          Jeep                11                     9.95
# 25   Lamborghini                 8                     7.03
# 26    Land Rover                10                     8.73
# 29         Lotus                 4                     3.58
# 30      Maserati                 6                     5.17
# 31       Maybach                 3                     2.67
# 35            MG                 1                     0.83
# 36          MINI                 2                     1.67
# 38        Morgan                 3                     2.34
# 40    Oldsmobile                12                    10.35
# 41      Plymouth                 8                     7.17
# 43       Porsche                 7                     6.18
# 44           Ram                 1                     0.76
# 45   Rolls-Royce                 2                     1.89
# 46          Saab                11                     9.28
# 47        Saturn                 2                     1.78
# 48         Scion                 3                     2.41
#
#     Average_saleprice_per_order_in_Millions  Cluster Demand_Cluster
# 0                                      0.88        0     LOW EARNER
# 1                                      0.89        0     LOW EARNER
# 3                                      0.78        0     LOW EARNER
# 4                                      0.87        0     LOW EARNER
# 10                                     0.85        0     LOW EARNER
# 11                                     0.82        0     LOW EARNER
# 13                                     0.85        0     LOW EARNER
# 14                                     0.81        0     LOW EARNER
# 16                                     0.88        0     LOW EARNER
# 23                                     0.90        0     LOW EARNER
# 25                                     0.88        0     LOW EARNER
# 26                                     0.87        0     LOW EARNER
# 29                                     0.90        0     LOW EARNER
# 30                                     0.86        0     LOW EARNER
# 31                                     0.89        0     LOW EARNER
# 35                                     0.83        0     LOW EARNER
# 36                                     0.84        0     LOW EARNER
# 38                                     0.78        0     LOW EARNER
# 40                                     0.86        0     LOW EARNER
# 41                                     0.90        0     LOW EARNER
# 43                                     0.88        0     LOW EARNER
# 44                                     0.76        0     LOW EARNER
# 45                                     0.95        0     LOW EARNER
# 46                                     0.84        0     LOW EARNER
# 47                                     0.89        0     LOW EARNER
# 48                                     0.80        0     LOW EARNER

# %%
#Check the spread of the Number of Orders, Total Sales(in Millions) of the 3 clusters
g=sns.pairplot(temp,
 y_vars=["Demand_Cluster"],
x_vars=["number_of_orders","Total_sales_in_Millions"],hue="Demand_Cluster",height=5)
g._legend.set_bbox_to_anchor((1.1, 0.8))
plt.show(g)

# %% [markdown]
# ## 3.2 Clustering/segmentation of State using KMeans algo into HIGH DEMAND, MEDIUM DEMAND and LOW DEMAND

# %%
#Executing SQL queries using Python to pull the State related data from the database.
query = '''select State,count(*) as number_of_orders, ROUND(sum(Sales)/1000000, 2) as Total_sales_in_Millions,ROUND((sum(Sales)/count(*))/1000000 , 2)  as Average_saleprice_per_order_in_Millions from temp group by State;'''
df = pd.read_sql_query(query,engine)

# %%
#Create 3 Clusters using KMeans algo based on the columns Average_saleprice_per_order_in_Millions & number_of_orders from the dataframe named df
kmeans = KMeans(n_clusters=3, random_state=0).fit(df[['Average_saleprice_per_order_in_Millions','number_of_orders']])
kmeans.labels_
# Out:
# array([0, 2, 0, 2, 1, 0, 0, 2, 0, 1, 0, 2, 2, 0, 0, 2, 2, 2, 0, 2, 2, 2,
#        0, 0, 2, 0, 2, 2, 0, 2, 2, 2, 1, 0, 2, 0, 0, 2, 0, 2, 0, 1, 2, 2,
#        0, 0, 2, 2, 2])

# %%
#Creating a temporary dataframe to store the Cluster values created using KMeans algorithm
temp=pd.DataFrame(kmeans.labels_)
temp.columns = ['Cluster']

# %%
#Concatenating the original dataframe along with a new column which contains the Clustering values returned by the KMeans algorithm
temp = pd.concat([df, temp], axis=1, join_axes=[df.index])
# Out:
# C:\Users\mdami\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.

# %%
#Creating a new column named Demand_Cluster based on the Clustering values returned by KMeans algo
#if KMeans value =1 then HIGH DEMAND
#if KMeans value =2 then MEDIUM DEMAND
#if KMeans value =0 then LOW DEMAND
temp.loc[temp.Cluster ==0, 'Demand_Cluster'] = 'MEDIUM DEMAND' 
temp.loc[temp.Cluster ==1, 'Demand_Cluster'] = 'HIGH DEMAND' 
temp.loc[temp.Cluster ==2, 'Demand_Cluster'] = 'LOW DEMAND'

# %%
#Original View based on the Number of Orders and Average Selling Price per Order (in Million $), points are colored by State
g=sns.lmplot( x='Average_saleprice_per_order_in_Millions', y='number_of_orders', data=df, fit_reg=False, hue='State', legend=True,height=8)
g.set_axis_labels("Average Selling Price per Order (in Million $)",
 "Number of Orders")

# %%
#Clustered View based on Number of Orders and Average Selling Price per Order (in Million $), points are colored by Clustering values
g=sns.lmplot( y='number_of_orders',x='Average_saleprice_per_order_in_Millions', data=temp, fit_reg=False, hue='Demand_Cluster', legend=True,height=8)
g.set_axis_labels("Average Selling Price per Order (in Million $)", "Number of Orders")
plt.show(g)

# %%
#A view of the final data frame consisting of the Car Brand data and Cluster column(gives values that was generated using KMeans algo)
#and Demand_Cluster column(gives values as HIGH DEMAND, MEDIUM DEMAND AND LOW DEMAND based on Clustering values)
temp
# Out:
#                    State  number_of_orders  Total_sales_in_Millions  \
# 0                Alabama                29                    25.26
# 1                 Alaska                10                     8.28
# 2                Arizona                26                    21.44
# 3               Arkansas                 6                     5.01
# 4             California                97                    83.41
# 5               Colorado                33                    27.62
# 6            Connecticut                22                    19.69
# 7               Delaware                 6                     5.21
# 8   District of Columbia                35                    30.13
# 9                Florida                86                    73.50
# 10               Georgia                18                    16.02
# 11                Hawaii                 6                     5.05
# 12                 Idaho                 7                     5.76
# 13              Illinois                25                    22.59
# 14               Indiana                21                    17.53
# 15                  Iowa                11                     9.16
# 16                Kansas                13                    11.29
# 17              Kentucky                 8                     6.79
# 18             Louisiana                21                    17.70
# 19                 Maine                 1                     0.81
# 20              Maryland                14                    12.03
# 21         Massachusetts                14                    12.20
# 22              Michigan                17                    14.44
# 23             Minnesota                18                    14.97
# 24           Mississippi                 2                     1.75
# 25              Missouri                23                    19.54
# 26               Montana                 3                     2.47
# 27              Nebraska                 7                     6.12
# 28                Nevada                17                    14.89
# 29         New Hampshire                 3                     2.69
# 30            New Jersey                 9                     7.62
# 31            New Mexico                 5                     4.00
# 32              New York                69                    59.29
# 33        North Carolina                20                    17.10
# 34          North Dakota                 2                     1.75
# 35                  Ohio                33                    27.29
# 36              Oklahoma                16                    13.56
# 37                Oregon                 8                     7.03
# 38          Pennsylvania                25                    21.48
# 39        South Carolina                 9                     7.72
# 40             Tennessee                23                    19.24
# 41                 Texas               100                    84.59
# 42                  Utah                10                     8.59
# 43               Vermont                 1                     0.97
# 44              Virginia                24                    20.12
# 45            Washington                28                    23.60
# 46         West Virginia                10                     8.39
# 47             Wisconsin                 8                     6.66
# 48               Wyoming                 1                     0.79
#
#     Average_saleprice_per_order_in_Millions  Cluster Demand_Cluster
# 0                                      0.87        0  MEDIUM DEMAND
# 1                                      0.83        2     LOW DEMAND
# 2                                      0.82        0  MEDIUM DEMAND
# 3                                      0.83        2     LOW DEMAND
# 4                                      0.86        1    HIGH DEMAND
# 5                                      0.84        0  MEDIUM DEMAND
# 6                                      0.89        0  MEDIUM DEMAND
# 7                                      0.87        2     LOW DEMAND
# 8                                      0.86        0  MEDIUM DEMAND
# 9                                      0.85        1    HIGH DEMAND
# 10                                     0.89        0  MEDIUM DEMAND
# 11                                     0.84        2     LOW DEMAND
# 12                                     0.82        2     LOW DEMAND
# 13                                     0.90        0  MEDIUM DEMAND
# 14                                     0.83        0  MEDIUM DEMAND
# 15                                     0.83        2     LOW DEMAND
# 16                                     0.87        2     LOW DEMAND
# 17                                     0.85        2     LOW DEMAND
# 18                                     0.84        0  MEDIUM DEMAND
# 19                                     0.81        2     LOW DEMAND
# 20                                     0.86        2     LOW DEMAND
# 21                                     0.87        2     LOW DEMAND
# 22                                     0.85        0  MEDIUM DEMAND
# 23                                     0.83        0  MEDIUM DEMAND
# 24                                     0.88        2     LOW DEMAND
# 25                                     0.85        0  MEDIUM DEMAND
# 26                                     0.82        2     LOW DEMAND
# 27                                     0.87        2     LOW DEMAND
# 28                                     0.88        0  MEDIUM DEMAND
# 29                                     0.90        2     LOW DEMAND
# 30                                     0.85        2     LOW DEMAND
# 31                                     0.80        2     LOW DEMAND
# 32                                     0.86        1    HIGH DEMAND
# 33                                     0.86        0  MEDIUM DEMAND
# 34                                     0.87        2     LOW DEMAND
# 35                                     0.83        0  MEDIUM DEMAND
# 36                                     0.85        0  MEDIUM DEMAND
# 37                                     0.88        2     LOW DEMAND
# 38                                     0.86        0  MEDIUM DEMAND
# 39                                     0.86        2     LOW DEMAND
# 40                                     0.84        0  MEDIUM DEMAND
# 41                                     0.85        1    HIGH DEMAND
# 42                                     0.86        2     LOW DEMAND
# 43                                     0.97        2     LOW DEMAND
# 44                                     0.84        0  MEDIUM DEMAND
# 45                                     0.84        0  MEDIUM DEMAND
# 46                                     0.84        2     LOW DEMAND
# 47                                     0.83        2     LOW DEMAND
# 48                                     0.79        2     LOW DEMAND

# %%
#Lets check the State from the HIGH DEMAND cluster
temp[temp['Cluster']==1]
# Out:
#          State  number_of_orders  Total_sales_in_Millions  \
# 4   California                97                    83.41
# 9      Florida                86                    73.50
# 32    New York                69                    59.29
# 41       Texas               100                    84.59
#
#     Average_saleprice_per_order_in_Millions  Cluster Demand_Cluster
# 4                                      0.86        1    HIGH DEMAND
# 9                                      0.85        1    HIGH DEMAND
# 32                                     0.86        1    HIGH DEMAND
# 41                                     0.85        1    HIGH DEMAND

# %%
#Lets check the State from the MEDIUM DEMAND cluster
temp[temp['Cluster']==0]
# Out:
#                    State  number_of_orders  Total_sales_in_Millions  \
# 0                Alabama                29                    25.26
# 2                Arizona                26                    21.44
# 5               Colorado                33                    27.62
# 6            Connecticut                22                    19.69
# 8   District of Columbia                35                    30.13
# 10               Georgia                18                    16.02
# 13              Illinois                25                    22.59
# 14               Indiana                21                    17.53
# 18             Louisiana                21                    17.70
# 22              Michigan                17                    14.44
# 23             Minnesota                18                    14.97
# 25              Missouri                23                    19.54
# 28                Nevada                17                    14.89
# 33        North Carolina                20                    17.10
# 35                  Ohio                33                    27.29
# 36              Oklahoma                16                    13.56
# 38          Pennsylvania                25                    21.48
# 40             Tennessee                23                    19.24
# 44              Virginia                24                    20.12
# 45            Washington                28                    23.60
#
#     Average_saleprice_per_order_in_Millions  Cluster Demand_Cluster
# 0                                      0.87        0  MEDIUM DEMAND
# 2                                      0.82        0  MEDIUM DEMAND
# 5                                      0.84        0  MEDIUM DEMAND
# 6                                      0.89        0  MEDIUM DEMAND
# 8                                      0.86        0  MEDIUM DEMAND
# 10                                     0.89        0  MEDIUM DEMAND
# 13                                     0.90        0  MEDIUM DEMAND
# 14                                     0.83        0  MEDIUM DEMAND
# 18                                     0.84        0  MEDIUM DEMAND
# 22                                     0.85        0  MEDIUM DEMAND
# 23                                     0.83        0  MEDIUM DEMAND
# 25                                     0.85        0  MEDIUM DEMAND
# 28                                     0.88        0  MEDIUM DEMAND
# 33                                     0.86        0  MEDIUM DEMAND
# 35                                     0.83        0  MEDIUM DEMAND
# 36                                     0.85        0  MEDIUM DEMAND
# 38                                     0.86        0  MEDIUM DEMAND
# 40                                     0.84        0  MEDIUM DEMAND
# 44                                     0.84        0  MEDIUM DEMAND
# 45                                     0.84        0  MEDIUM DEMAND

# %%
#Lets check the State from the LOW DEMAND cluster
temp[temp['Cluster']==2]
# Out:
#              State  number_of_orders  Total_sales_in_Millions  \
# 1           Alaska                10                     8.28
# 3         Arkansas                 6                     5.01
# 7         Delaware                 6                     5.21
# 11          Hawaii                 6                     5.05
# 12           Idaho                 7                     5.76
# 15            Iowa                11                     9.16
# 16          Kansas                13                    11.29
# 17        Kentucky                 8                     6.79
# 19           Maine                 1                     0.81
# 20        Maryland                14                    12.03
# 21   Massachusetts                14                    12.20
# 24     Mississippi                 2                     1.75
# 26         Montana                 3                     2.47
# 27        Nebraska                 7                     6.12
# 29   New Hampshire                 3                     2.69
# 30      New Jersey                 9                     7.62
# 31      New Mexico                 5                     4.00
# 34    North Dakota                 2                     1.75
# 37          Oregon                 8                     7.03
# 39  South Carolina                 9                     7.72
# 42            Utah                10                     8.59
# 43         Vermont                 1                     0.97
# 46   West Virginia                10                     8.39
# 47       Wisconsin                 8                     6.66
# 48         Wyoming                 1                     0.79
#
#     Average_saleprice_per_order_in_Millions  Cluster Demand_Cluster
# 1                                      0.83        2     LOW DEMAND
# 3                                      0.83        2     LOW DEMAND
# 7                                      0.87        2     LOW DEMAND
# 11                                     0.84        2     LOW DEMAND
# 12                                     0.82        2     LOW DEMAND
# 15                                     0.83        2     LOW DEMAND
# 16                                     0.87        2     LOW DEMAND
# 17                                     0.85        2     LOW DEMAND
# 19                                     0.81        2     LOW DEMAND
# 20                                     0.86        2     LOW DEMAND
# 21                                     0.87        2     LOW DEMAND
# 24                                     0.88        2     LOW DEMAND
# 26                                     0.82        2     LOW DEMAND
# 27                                     0.87        2     LOW DEMAND
# 29                                     0.90        2     LOW DEMAND
# 30                                     0.85        2     LOW DEMAND
# 31                                     0.80        2     LOW DEMAND
# 34                                     0.87        2     LOW DEMAND
# 37                                     0.88        2     LOW DEMAND
# 39                                     0.86        2     LOW DEMAND
# 42                                     0.86        2     LOW DEMAND
# 43                                     0.97        2     LOW DEMAND
# 46                                     0.84        2     LOW DEMAND
# 47                                     0.83        2     LOW DEMAND
# 48                                     0.79        2     LOW DEMAND

# %%
#Check the spread of the Number of Orders, Total Sales(in Millions) of the 3 clusters
g=sns.pairplot(temp,
y_vars=["Demand_Cluster"],
x_vars=["number_of_orders","Total_sales_in_Millions"],hue="Demand_Cluster",height=5)
g._legend.set_bbox_to_anchor((1.1, 0.8))
plt.show(g)
